# %% [markdown]
# # <span style="color:#756bb1">UNIVARIATE ANALYSIS</span>

# %% [markdown]
# ## <span style="color:#e6550d">2.1 Data Vectors</span>

# %% [markdown]
# ### <span style="color:#31a354">Data types: <b><i>Date and time types</i></b></span>

# %%
# Install the packages 
#install.packages("lubridate")
library(lubridate) # upload the entire package
#require(lubridate) # upload the package partially

# %%
### Data types: Date and time types -------------------------------------------
now()
current_time <- now()
class(current_time)
# The Posixct class records a moment in time like
# the number of seconds since the beginning of 1970,
# if the value in negative it means that the date is before 1970
# Out:
# [1] "2024-01-09 10:45:51 CET"
# [1] "POSIXct" "POSIXt"

# %%
as.numeric(current_time)
# current time
# cf. ?POSIXct

month(current_time, label=TRUE)   
month(current_time, label=F)
# Out:
# [1] 1704793551
# [1] Jan
# 12 Levels: Jan < Feb < Mar < Apr < May < Jun < Jul < Aug < Sep < ... < Dec
# [1] 1

# %%
mode(current_time) # mode of the object
# Out:
# [1] "numeric"

# %%
str(current_time) # structure of the object
# Out:
#  POSIXct[1:1], format: "2024-01-09 10:45:51"

# %%
# In addition to the use of `Now`, it is possible to create times in other ways. 
# One of these modalities is through the function `parse_date_time`
#? parse_date_time
x <- c("09-01-01", "09-01-02", "09-01-03")
x
mode(x)

parse_date_time(x, "ymd", tz="CET")
parse_date_time(x, "y m d", tz = "Europe/Rome")
parse_date_time(x, "%y%m%d")
# Out:
# [1] "09-01-01" "09-01-02" "09-01-03"
# [1] "character"
# [1] "2009-01-01 CET" "2009-01-02 CET" "2009-01-03 CET"
# [1] "2009-01-01 CET" "2009-01-02 CET" "2009-01-03 CET"
# [1] "2009-01-01 UTC" "2009-01-02 UTC" "2009-01-03 UTC"

# %%
# same as now function
# useful to calculate the computational time
u <- Sys.time()
u

#Calculate the difference between two dates
u - current_time

# switch the time zone
attr(u, "tzone") <- "UTC"
u

x <- "15-Feb-2013 07:57:34"
y <- parse_date_time(x, "dbYHMS") # day and month are db to avoid confusion
y
year(y)                                 

# working with dates
now() - days(1)
now() - hours(24)

# Create a data object
# sequence of days
days_sequence <- seq(dmy("01-01-2020"), dmy("31-12-2021"), by = "days")
days_sequence

# sequence of months
month_sequence <- seq(ymd("2020-01-01"), ymd("2020-12-31"), by = "months")
month_sequence

mode(days_sequence)
str(days_sequence)
length(days_sequence)
# Out:
# [1] "2024-01-09 10:45:51 CET"
# Time difference of 0.05698395 secs
# [1] "2024-01-09 09:45:51 UTC"
# [1] "2013-02-15 07:57:34 UTC"
# [1] 2013
# [1] "2024-01-08 10:45:51 CET"
# [1] "2024-01-08 10:45:51 CET"
#   [1] "2020-01-01" "2020-01-02" "2020-01-03" "2020-01-04" "2020-01-05"
#   [6] "2020-01-06" "2020-01-07" "2020-01-08" "2020-01-09" "2020-01-10"
#  [11] "2020-01-11" "2020-01-12" "2020-01-13" "2020-01-14" "2020-01-15"
#  [16] "2020-01-16" "2020-01-17" "2020-01-18" "2020-01-19" "2020-01-20"
#  [21] "2020-01-21" "2020-01-22" "2020-01-23" "2020-01-24" "2020-01-25"
# [706] "2021-12-06" "2021-12-07" "2021-12-08" "2021-12-09" "2021-12-10"
# [711] "2021-12-11" "2021-12-12" "2021-12-13" "2021-12-14" "2021-12-15"
# [716] "2021-12-16" "2021-12-17" "2021-12-18" "2021-12-19" "2021-12-20"
# [721] "2021-12-21" "2021-12-22" "2021-12-23" "2021-12-24" "2021-12-25"
# [726] "2021-12-26" "2021-12-27" "2021-12-28" "2021-12-29" "2021-12-30"
# [731] "2021-12-31"
#  [1] "2020-01-01" "2020-02-01" "2020-03-01" "2020-04-01" "2020-05-01"
#  [6] "2020-06-01" "2020-07-01" "2020-08-01" "2020-09-01" "2020-10-01"
# [11] "2020-11-01" "2020-12-01"
# [1] "numeric"
#  Date[1:731], format: "2020-01-01" "2020-01-02" "2020-01-03" "2020-01-04" "2020-01-05" ...
# [1] 731

# %%
# Exercise: Days from my birhday
my_birthday <- ymd("1981-12-03")
my_birthday
current_day <- Sys.Date()
current_day
days_from_my_birthday <- as.numeric(current_day - my_birthday)
days_from_my_birthday
# Out:
# [1] "1981-12-03"
# [1] "2024-01-09"
# [1] 15377

# %%
# Other useful functions
# Any, All, Which and % in % functions for vectors

# runif generates random numbers from a uniform distribution
x<-round(runif(10)*10,0) 
x
any(x == 0)
all(x <= 10)
which(x > 5)
x %in% 0
# Out:
#  [1] 2 8 3 5 9 2 5 9 4 2
# [1] FALSE
# [1] TRUE
# [1] 2 5 8
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE

# %% [markdown]
# ### <span style="color:#31a354">Data types: <b><i>Factors</i></b></span>
# ### Data Pre-Processing

# %%
library(readr)

# %%
AcquistiOnLine <- read_csv("/Users/marcosau/IADA/2023-24 3-1/Statistica Computazionale/SC Lab/09/AcquistiOnLine.csv")
# Out:
# New names:
# * `` -> `...1`
# Rows: 100 Columns: 11
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr  (4): Nome, Genere, Area_geografica, Livello_istruzione
# dbl  (5): ...1, Età, Spesa_media_mensile, Prezzo_acquisto, Numero_pagine_vis...
# lgl  (1): Acquisto_online
# date (1): data_contatto
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
summary(AcquistiOnLine)
# Out:
#       ...1        data_contatto            Nome              Genere
#  Min.   :  1.00   Min.   :2020-01-03   Length:100         Length:100
#  1st Qu.: 25.75   1st Qu.:2020-06-25   Class :character   Class :character
#  Median : 50.50   Median :2020-12-16   Mode  :character   Mode  :character
#  Mean   : 50.50   Mean   :2021-01-01
#  3rd Qu.: 75.25   3rd Qu.:2021-07-16
#  Max.   :100.00   Max.   :2021-12-27
#       Et<U+00E0>        Area_geografica    Livello_istruzione Acquisto_online
#  Min.   :30.00   Length:100         Length:100         Mode :logical
#  1st Qu.:36.00   Class :character   Class :character   FALSE:53
#  Median :43.00   Mode  :character   Mode  :character   TRUE :47
#  Mean   :43.02
#  3rd Qu.:50.00
#  Max.   :55.00
#  Spesa_media_mensile Prezzo_acquisto Numero_pagine_visitate
#  Min.   : 44.38      Min.   : 0.00   Min.   :1.00
#  1st Qu.: 69.56      1st Qu.: 0.00   1st Qu.:2.00
#  Median : 77.91      Median : 0.00   Median :3.00
#  Mean   : 76.36      Mean   :25.69   Mean   :3.02
#  3rd Qu.: 86.22      3rd Qu.:53.45   3rd Qu.:4.00
#  Max.   :103.94      Max.   :99.69   Max.   :7.00

# %%
AcquistiOnLine <- AcquistiOnLine[,-1] # delete the first column
summary(AcquistiOnLine)
# Out:
#  data_contatto            Nome              Genere               Et<U+00E0>
#  Min.   :2020-01-03   Length:100         Length:100         Min.   :30.00
#  1st Qu.:2020-06-25   Class :character   Class :character   1st Qu.:36.00
#  Median :2020-12-16   Mode  :character   Mode  :character   Median :43.00
#  Mean   :2021-01-01                                         Mean   :43.02
#  3rd Qu.:2021-07-16                                         3rd Qu.:50.00
#  Max.   :2021-12-27                                         Max.   :55.00
#  Area_geografica    Livello_istruzione Acquisto_online Spesa_media_mensile
#  Length:100         Length:100         Mode :logical   Min.   : 44.38
#  Class :character   Class :character   FALSE:53        1st Qu.: 69.56
#  Mode  :character   Mode  :character   TRUE :47        Median : 77.91
#                                                        Mean   : 76.36
#                                                        3rd Qu.: 86.22
#                                                        Max.   :103.94
#  Prezzo_acquisto Numero_pagine_visitate
#  Min.   : 0.00   Min.   :1.00
#  1st Qu.: 0.00   1st Qu.:2.00
#  Median : 0.00   Median :3.00
#  Mean   :25.69   Mean   :3.02
#  3rd Qu.:53.45   3rd Qu.:4.00
#  Max.   :99.69   Max.   :7.00

# %%
# With the function `str` we can see the structure of the data
str(AcquistiOnLine)
# Out:
# tibble [100 x 10] (S3: tbl_df/tbl/data.frame)
#  $ data_contatto         : Date[1:100], format: "2021-07-14" "2020-11-16" ...
#  $ Nome                  : chr [1:100] "nupwahy" "yhru" "gzj" "vwkasjmxz" ...
#  $ Genere                : chr [1:100] "Maschio" "Maschio" "Maschio" "Femmina" ...
#  $ Et<U+00E0>            : num [1:100] 32 34 50 54 45 49 55 32 32 51 ...
#  $ Area_geografica       : chr [1:100] "Nord" "Centro" "Nord" "Centro" ...
#  $ Livello_istruzione    : chr [1:100] "Diploma" "Diploma" "Diploma" "Dottorato" ...
#  $ Acquisto_online       : logi [1:100] FALSE FALSE TRUE FALSE FALSE FALSE ...
#  $ Spesa_media_mensile   : num [1:100] 54.8 61.4 74.1 82.4 102.3 ...
#  $ Prezzo_acquisto       : num [1:100] 0 0 26.9 0 0 ...
#  $ Numero_pagine_visitate: num [1:100] 2 4 3 5 5 1 3 5 3 3 ...

# %%
# Convert the variables into factors
AcquistiOnLine$Genere <- as.factor(AcquistiOnLine$Genere)
AcquistiOnLine$Genere

str(AcquistiOnLine)
# Out:
#   [1] Maschio Maschio Maschio Femmina Femmina Maschio Femmina Femmina Maschio
#  [10] Femmina Femmina Maschio Femmina Femmina Maschio Maschio Femmina Maschio
#  [19] Maschio Maschio Femmina Maschio Maschio Maschio Maschio Femmina Femmina
#  [28] Femmina Femmina Femmina Maschio Maschio Femmina Femmina Maschio Maschio
#  [37] Femmina Femmina Maschio Maschio Femmina Femmina Femmina Femmina Femmina
#  [46] Maschio Maschio Femmina Femmina Maschio Femmina Femmina Femmina Femmina
#  [55] Femmina Maschio Maschio Femmina Femmina Femmina Maschio Maschio Maschio
#  [64] Femmina Femmina Maschio Femmina Maschio Femmina Femmina Femmina Maschio
#  [73] Maschio Femmina Femmina Femmina Maschio Femmina Maschio Maschio Maschio
#  [82] Femmina Maschio Maschio Femmina Femmina Femmina Femmina Maschio Femmina
#  [91] Femmina Femmina Femmina Femmina Maschio Maschio Femmina Maschio Maschio
# [100] Femmina
# Levels: Femmina Maschio
# tibble [100 x 10] (S3: tbl_df/tbl/data.frame)
#  $ data_contatto         : Date[1:100], format: "2021-07-14" "2020-11-16" ...
#  $ Nome                  : chr [1:100] "nupwahy" "yhru" "gzj" "vwkasjmxz" ...
#  $ Genere                : Factor w/ 2 levels "Femmina","Maschio": 2 2 2 1 1 2 1 1 2 1 ...
#  $ Et<U+00E0>            : num [1:100] 32 34 50 54 45 49 55 32 32 51 ...
#  $ Area_geografica       : chr [1:100] "Nord" "Centro" "Nord" "Centro" ...
#  $ Livello_istruzione    : chr [1:100] "Diploma" "Diploma" "Diploma" "Dottorato" ...
#  $ Acquisto_online       : logi [1:100] FALSE FALSE TRUE FALSE FALSE FALSE ...
#  $ Spesa_media_mensile   : num [1:100] 54.8 61.4 74.1 82.4 102.3 ...
#  $ Prezzo_acquisto       : num [1:100] 0 0 26.9 0 0 ...
#  $ Numero_pagine_visitate: num [1:100] 2 4 3 5 5 1 3 5 3 3 ...

# %%
# Upload the data-set permanently on the memory
attach(AcquistiOnLine)
# Out:
# Warning message in attach(AcquistiOnLine):
# "unable to translate 'Et<U+00E0>' to native encoding"
# The following objects are masked _by_ .GlobalEnv:
#
#     Acquisto_online, Area_geografica, Livello_istruzione

# %%
# Convert the variables into factors into the attached data-set
Area_geografica <- as.factor(Area_geografica)
Area_geografica
str(AcquistiOnLine)
# Overwrite the variable in the data-set to be a factor
AcquistiOnLine$Area_geografica <- Area_geografica
# Out:
#   [1] Nord        Centro      Nord        Centro      Nord        Sud e isole
#   [7] Sud e isole Centro      Sud e isole Nord        Centro      Centro
#  [13] Sud e isole Centro      Nord        Sud e isole Sud e isole Sud e isole
#  [19] Centro      Centro      Sud e isole Nord        Nord        Sud e isole
#  [25] Centro      Centro      Centro      Centro      Centro      Centro
#  [31] Sud e isole Centro      Nord        Centro      Centro      Centro
#  [37] Sud e isole Centro      Sud e isole Centro      Sud e isole Nord
#  [43] Sud e isole Sud e isole Sud e isole Nord        Sud e isole Sud e isole
#  [49] Centro      Centro      Centro      Sud e isole Sud e isole Sud e isole
#  [55] Centro      Nord        Centro      Nord        Sud e isole Sud e isole
#  [61] Centro      Nord        Sud e isole Nord        Sud e isole Centro
#  [67] Centro      Nord        Sud e isole Centro      Nord        Sud e isole
#  [73] Sud e isole Sud e isole Nord        Centro      Centro      Nord
#  [79] Centro      Sud e isole Sud e isole Nord        Centro      Nord
#  [85] Centro      Sud e isole Sud e isole Nord        Sud e isole Centro
#  [91] Nord        Nord        Centro      Sud e isole Nord        Centro
#  [97] Centro      Nord        Centro      Nord
# Levels: Centro Nord Sud e isole
# tibble [100 x 10] (S3: tbl_df/tbl/data.frame)
#  $ data_contatto         : Date[1:100], format: "2021-07-14" "2020-11-16" ...
#  $ Nome                  : chr [1:100] "nupwahy" "yhru" "gzj" "vwkasjmxz" ...
#  $ Genere                : Factor w/ 2 levels "Femmina","Maschio": 2 2 2 1 1 2 1 1 2 1 ...
#  $ Et<U+00E0>            : num [1:100] 32 34 50 54 45 49 55 32 32 51 ...
#  $ Area_geografica       : chr [1:100] "Nord" "Centro" "Nord" "Centro" ...
#  $ Livello_istruzione    : chr [1:100] "Diploma" "Diploma" "Diploma" "Dottorato" ...
#  $ Acquisto_online       : logi [1:100] FALSE FALSE TRUE FALSE FALSE FALSE ...
#  $ Spesa_media_mensile   : num [1:100] 54.8 61.4 74.1 82.4 102.3 ...
#  $ Prezzo_acquisto       : num [1:100] 0 0 26.9 0 0 ...
#  $ Numero_pagine_visitate: num [1:100] 2 4 3 5 5 1 3 5 3 3 ...

# %%
#? as.ordered
Livello_istruzione <- factor(Livello_istruzione, 
                        levels = c("Diploma","Laurea", "Master", "Dottorato"),
                           ordered = TRUE) 
Livello_istruzione
AcquistiOnLine$Livello_istruzione<-Livello_istruzione
str(AcquistiOnLine)
# Out:
#   [1] Diploma   Diploma   Diploma   Dottorato Diploma   Dottorato Diploma
#   [8] Diploma   Laurea    Laurea    Laurea    Dottorato Master    Laurea
#  [15] Dottorato Laurea    Laurea    Diploma   Laurea    Dottorato Master
#  [22] Dottorato Diploma   Master    Master    Master    Diploma   Dottorato
#  [29] Master    Laurea    Dottorato Diploma   Master    Laurea    Laurea
#  [36] Master    Master    Master    Diploma   Diploma   Dottorato Master
#  [43] Master    Diploma   Master    Dottorato Dottorato Laurea    Master
#  [50] Dottorato Master    Diploma   Diploma   Diploma   Diploma   Laurea
#  [57] Laurea    Master    Master    Laurea    Diploma   Dottorato Dottorato
#  [64] Dottorato Diploma   Master    Laurea    Diploma   Dottorato Diploma
#  [71] Laurea    Master    Diploma   Dottorato Laurea    Dottorato Dottorato
#  [78] Dottorato Diploma   Laurea    Master    Laurea    Diploma   Dottorato
#  [85] Master    Master    Dottorato Dottorato Diploma   Laurea    Diploma
#  [92] Diploma   Diploma   Master    Dottorato Master    Laurea    Laurea
#  [99] Laurea    Dottorato
# Levels: Diploma < Laurea < Master < Dottorato
# tibble [100 x 10] (S3: tbl_df/tbl/data.frame)
#  $ data_contatto         : Date[1:100], format: "2021-07-14" "2020-11-16" ...
#  $ Nome                  : chr [1:100] "nupwahy" "yhru" "gzj" "vwkasjmxz" ...
#  $ Genere                : Factor w/ 2 levels "Femmina","Maschio": 2 2 2 1 1 2 1 1 2 1 ...
#  $ Et<U+00E0>            : num [1:100] 32 34 50 54 45 49 55 32 32 51 ...
#  $ Area_geografica       : Factor w/ 3 levels "Centro","Nord",..: 2 1 2 1 2 3 3 1 3 2 ...
#  $ Livello_istruzione    : Ord.factor w/ 4 levels "Diploma"<"Laurea"<..: 1 1 1 4 1 4 1 1 2 2 ...
#  $ Acquisto_online       : logi [1:100] FALSE FALSE TRUE FALSE FALSE FALSE ...
#  $ Spesa_media_mensile   : num [1:100] 54.8 61.4 74.1 82.4 102.3 ...
#  $ Prezzo_acquisto       : num [1:100] 0 0 26.9 0 0 ...
#  $ Numero_pagine_visitate: num [1:100] 2 4 3 5 5 1 3 5 3 3 ...

# %%
Acquisto_online

# Convert a logical variable into a factor
Acquisto_online[Acquisto_online == FALSE] <- "No"
Acquisto_online[Acquisto_online == TRUE] <- "Si"
Acquisto_online
Acquisto_online <- factor(Acquisto_online, levels = c("No", "Si"))
Acquisto_online

str(AcquistiOnLine)
# Out:
#   [1] No No Si No No No Si Si No Si Si Si No No No Si Si Si No Si No No No Si Si
#  [26] Si Si No No No Si No No No No No Si Si No No No No Si Si Si Si Si No No Si
#  [51] No No Si No No Si No Si No Si Si No No No Si Si Si Si No No No No No Si No
#  [76] Si Si No Si Si Si No No Si Si Si Si Si No Si Si No No No No No Si No No Si
# Levels: No Si
#   [1] No No Si No No No Si Si No Si Si Si No No No Si Si Si No Si No No No Si Si
#  [26] Si Si No No No Si No No No No No Si Si No No No No Si Si Si Si Si No No Si
#  [51] No No Si No No Si No Si No Si Si No No No Si Si Si Si No No No No No Si No
#  [76] Si Si No Si Si Si No No Si Si Si Si Si No Si Si No No No No No Si No No Si
# Levels: No Si
#   [1] No No Si No No No Si Si No Si Si Si No No No Si Si Si No Si No No No Si Si
#  [26] Si Si No No No Si No No No No No Si Si No No No No Si Si Si Si Si No No Si
#  [51] No No Si No No Si No Si No Si Si No No No Si Si Si Si No No No No No Si No
#  [76] Si Si No Si Si Si No No Si Si Si Si Si No Si Si No No No No No Si No No Si
# Levels: No Si
# tibble [100 x 10] (S3: tbl_df/tbl/data.frame)
#  $ data_contatto         : Date[1:100], format: "2021-07-14" "2020-11-16" ...
#  $ Nome                  : chr [1:100] "nupwahy" "yhru" "gzj" "vwkasjmxz" ...
#  $ Genere                : Factor w/ 2 levels "Femmina","Maschio": 2 2 2 1 1 2 1 1 2 1 ...
#  $ Et<U+00E0>            : num [1:100] 32 34 50 54 45 49 55 32 32 51 ...
#  $ Area_geografica       : Factor w/ 3 levels "Centro","Nord",..: 2 1 2 1 2 3 3 1 3 2 ...
#  $ Livello_istruzione    : Ord.factor w/ 4 levels "Diploma"<"Laurea"<..: 1 1 1 4 1 4 1 1 2 2 ...
#  $ Acquisto_online       : logi [1:100] FALSE FALSE TRUE FALSE FALSE FALSE ...
#  $ Spesa_media_mensile   : num [1:100] 54.8 61.4 74.1 82.4 102.3 ...
#  $ Prezzo_acquisto       : num [1:100] 0 0 26.9 0 0 ...
#  $ Numero_pagine_visitate: num [1:100] 2 4 3 5 5 1 3 5 3 3 ...

# %%
AcquistiOnLine$Acquisto_online <- Acquisto_online

str(AcquistiOnLine)
# Out:
# tibble [100 x 10] (S3: tbl_df/tbl/data.frame)
#  $ data_contatto         : Date[1:100], format: "2021-07-14" "2020-11-16" ...
#  $ Nome                  : chr [1:100] "nupwahy" "yhru" "gzj" "vwkasjmxz" ...
#  $ Genere                : Factor w/ 2 levels "Femmina","Maschio": 2 2 2 1 1 2 1 1 2 1 ...
#  $ Et<U+00E0>            : num [1:100] 32 34 50 54 45 49 55 32 32 51 ...
#  $ Area_geografica       : Factor w/ 3 levels "Centro","Nord",..: 2 1 2 1 2 3 3 1 3 2 ...
#  $ Livello_istruzione    : Ord.factor w/ 4 levels "Diploma"<"Laurea"<..: 1 1 1 4 1 4 1 1 2 2 ...
#  $ Acquisto_online       : Factor w/ 2 levels "No","Si": 1 1 2 1 1 1 2 2 1 2 ...
#  $ Spesa_media_mensile   : num [1:100] 54.8 61.4 74.1 82.4 102.3 ...
#  $ Prezzo_acquisto       : num [1:100] 0 0 26.9 0 0 ...
#  $ Numero_pagine_visitate: num [1:100] 2 4 3 5 5 1 3 5 3 3 ...

# %% [markdown]
# ## <span style="color:#e6550d">Variabili Numeriche</br>2.3 Numeric Summaries</span>

# %% [markdown]
# ### <span style="color:#31a354">Central trend indicators</span>
# Indici di tendenza centrale

# %% [markdown]
# #### <span style="color:#3182bd">Mean</span>

# %%
mean(Prezzo_acquisto)

# Trimmed mean
mean(Prezzo_acquisto, trim = 0.05) # truncated mean
# Exclude 5 percent of the observations from the extremes

# Weighted mean
# Media of the weighted purchase price for the number of pages visited
mean(Prezzo_acquisto*(Numero_pagine_visitate/sum(Numero_pagine_visitate)))

# Calculate the weighted mean
weighted_mean <- weighted.mean(Prezzo_acquisto, Numero_pagine_visitate)

# Print the result
print(weighted_mean)
# Out:
# [1] 25.69444
# [1] 23.28393
# [1] 0.2783633
# [1] 27.83633

# %% [markdown]
# #### <span style="color:#3182bd">Median</span>

# %%
# median means the value that divides the sample in half
median(Prezzo_acquisto)
median(Numero_pagine_visitate)

# calculate for the qualitative variables
as.numeric(Livello_istruzione) # first convert the variable into numeric
median(as.numeric(Livello_istruzione))
# Out:
# [1] 0
# [1] 3
#   [1] 1 1 1 4 1 4 1 1 2 2 2 4 3 2 4 2 2 1 2 4 3 4 1 3 3 3 1 4 3 2 4 1 3 2 2 3 3
#  [38] 3 1 1 4 3 3 1 3 4 4 2 3 4 3 1 1 1 1 2 2 3 3 2 1 4 4 4 1 3 2 1 4 1 2 3 1 4
#  [75] 2 4 4 4 1 2 3 2 1 4 3 3 4 4 1 2 1 1 1 3 4 3 2 2 2 4
# [1] 2

# %% [markdown]
# #### <span style="color:#3182bd">Quantiles</span>

# %%
#? quantile
quantile(Prezzo_acquisto)
quantile(Prezzo_acquisto, probs = c(0.01,0.05,.25,.75,.95,.99))

#? fivenum
# Useful to build the boxplot
fivenum(Prezzo_acquisto)
#edit(fivenum)
# Out:
#       0%      25%      50%      75%     100%
#  0.00000  0.00000  0.00000 53.44572 99.68974
#       1%       5%      25%      75%      95%      99%
#  0.00000  0.00000  0.00000 53.44572 89.69480 97.12197
# [1]  0.00000  0.00000  0.00000 53.66353 99.68974

# %% [markdown]
# #### <span style="color:#3182bd">Mode</span>

# %%
Numero_pagine_visitate
x<-Area_geografica

# Using the table function
table(Area_geografica)
moda <- max(table(Area_geografica))

# Manually calculate the mode
#! Doesn't work with qualitative variables
moda<-function(x){
  flag<-0
  if(is.factor(x)){
    flag<-1
    x.old<-unique(x)
    x<-as.numeric(x)
  } 
  v<-unique(x)
  somme<-list()
  for(i in length(x))
    somme[[i]]<-sum(x[x == v[i]])
  ris<-v[which.max(somme)]
  if(flag == 1) ris<-x.old[ris]
  return(ris)
}

# moda(Numero_pagine_visitate)
# moda(Area_geografica) # doesn't work with qualitative variables

# my solution
#?sapply
sum_elements <- function(x, value) { # x is a vector, value is a scalar
  sum(x == value)
}

calculate_mode <- function(column) {
  unique_values <- unique(column)
  cat("Unique values:", unique_values, "\n")
#    frequencies <- sapply(unique_values, function(x) sum(column == x))
  frequencies <- sapply(unique_values, sum_elements, x = column)
  cat("Frequencies:", frequencies, "\n")
  max_freq <- max(frequencies)
  cat("Max frequency:", max_freq, "\n")
  mode_values <- unique_values[frequencies == max_freq]
  return(mode_values)
}

calculate_mode(Area_geografica)
calculate_mode(Numero_pagine_visitate)
# Out:
#   [1] 2 4 3 5 5 1 3 5 3 3 6 3 4 3 1 5 2 1 2 6 5 4 3 7 3 4 3 3 2 2 6 5 4 4 1 3 4
#  [38] 2 2 2 2 3 3 2 2 2 2 3 2 5 1 3 4 1 3 2 1 4 5 2 3 1 2 2 4 3 4 4 4 3 4 3 4 1
#  [75] 3 2 2 3 2 1 2 3 3 4 1 3 7 5 5 2 1 3 2 3 2 2 4 1 3 3
# Area_geografica
#      Centro        Nord Sud e isole
#          39          26          35
# Unique values: 2 1 3
# Frequencies: 26 39 35
# Max frequency: 39
# [1] Centro
# Levels: Centro Nord Sud e isole
# Unique values: 2 4 3 5 1 6 7
# Frequencies: 26 17 29 10 13 3 2
# Max frequency: 29
# [1] 3

# %% [markdown]
# ### <span style="color:#31a354">Spread indicators</span>
# Indici di variabilita'

# %% [markdown]
# #### <span style="color:#3182bd">Range</span>

# %%
#? range
range(Prezzo_acquisto)
max(Prezzo_acquisto)-min(Prezzo_acquisto)
# Out:
# [1]  0.00000 99.68974
# [1] 99.68974

# %% [markdown]
# #### <span style="color:#3182bd">Interquartile range</span>

# %%
#? IQR
IQR(Prezzo_acquisto)
# Out:
# [1] 53.44572

# %% [markdown]
# #### <span style="color:#3182bd">Variance</span>

# %%
#? var
var(Prezzo_acquisto) # sample variance
mean((Prezzo_acquisto - mean(Prezzo_acquisto))^2) # variance of the population

# multiply by (n-1)/n to get the population variance
# population variance
var(Prezzo_acquisto)*(length(Prezzo_acquisto)-1)/length(Prezzo_acquisto)
# Out:
# [1] 1042.22
# [1] 1031.797
# [1] 1031.797

# %% [markdown]
# #### <span style="color:#3182bd">Standard deviation</span>

# %%
#? sd
sd(Prezzo_acquisto) # Sample standard deviation
# If I know the population mean, I can calculate
# the population standard deviation

# population standard deviation
sqrt(mean((Prezzo_acquisto - mean(Prezzo_acquisto))^2))
sd(Prezzo_acquisto)*(length(Prezzo_acquisto)-1)/length(Prezzo_acquisto)
# Out:
# [1] 32.28343
# [1] 32.1216
# [1] 31.96059

# %% [markdown]
# #### <span style="color:#3182bd">Z-score</span>

# %%
par(bg = "white")
# Is the number of standard deviations that a given value x 
# is above or below the mean
# Neutralize the scale differences between variables
# mean = 0, sd = 1

# Manually build the z-score
z_score<-function(x){
  (x - mean(x)) / sd(x)
}
z_score(Prezzo_acquisto)
# Out:
#   [1] -0.795901737 -0.795901737  0.037597576 -0.795901737 -0.795901737
#   [6] -0.795901737  2.119961773  1.048526619 -0.795901737  0.063037563
#  [11]  1.005991709  0.014421677 -0.795901737 -0.795901737 -0.795901737
#  [16]  0.032671833  1.548202235  0.662075041 -0.795901737  0.852867216
#  [21] -0.795901737 -0.795901737 -0.795901737  1.165085318  1.728481092
#  [26]  1.657769588  2.073219886 -0.795901737 -0.795901737 -0.795901737
#  [31]  1.583151188 -0.795901737 -0.795901737 -0.795901737 -0.795901737
#  [36] -0.795901737  0.056574464  1.699801251 -0.795901737 -0.795901737
#  [41] -0.795901737 -0.795901737  0.996618612 -0.173051445  1.585719506
#  [46]  1.552621972  1.981393026 -0.795901737 -0.795901737  0.748285769
#  [51] -0.795901737 -0.795901737  2.211710528 -0.795901737 -0.795901737
#  [56]  0.237820567 -0.795901737  1.325583880 -0.795901737 -0.316229077
#  [61]  0.772022790 -0.795901737 -0.795901737 -0.795901737  1.039973606
#  [66]  2.002582895  0.879854430 -0.007667872 -0.795901737 -0.795901737
#  [71] -0.795901737 -0.795901737 -0.795901737  0.030863729 -0.795901737
#  [76]  0.198747114  0.492673463 -0.795901737  0.361621598 -0.437223913
#  [81]  2.292052405 -0.795901737 -0.795901737  1.939061783  1.059933714
#  [86]  0.688576922 -0.297586801  1.079036035 -0.795901737  0.103174894
#  [91]  1.046090992 -0.795901737 -0.795901737 -0.795901737 -0.795901737
#  [96] -0.795901737  0.445627540 -0.795901737 -0.795901737  0.993467390

# %%
# Using the scale function
pas <- scale(Prezzo_acquisto) # pas = prezzo di acquisto scalato
pas # numeric vector
# Out:
#       [,1]
#  [1,] -0.79590174
#  [2,] -0.79590174
#  [3,]  0.03759758
#  [4,] -0.79590174
#  [5,] -0.79590174
#  [6,] -0.79590174
#  [7,]  2.11996177
#  [8,]  1.04852662
#  [9,] -0.79590174
# [10,]  0.06303756
# [11,]  1.00599171
# [12,]  0.01442168
# [13,] -0.79590174
# [14,] -0.79590174
# [15,] -0.79590174
# [16,]  0.03267183
# [17,]  1.54820223
# [18,]  0.66207504
# [19,] -0.79590174
# [20,]  0.85286722
# [21,] -0.79590174
# [22,] -0.79590174
# [23,] -0.79590174
# [24,]  1.16508532
# [25,]  1.72848109
# [26,]  1.65776959
# [27,]  2.07321989
# [28,] -0.79590174
# [29,] -0.79590174
# [30,] -0.79590174
# [31,] ...
# [32,] -0.79590174
# [33,] -0.79590174
# [34,] -0.79590174
# [35,]  0.03086373
# [36,] -0.79590174
# [37,]  0.19874711
# [38,]  0.49267346
# [39,] -0.79590174
# [40,]  0.36162160
# [41,] -0.43722391
# [42,]  2.29205240
# [43,] -0.79590174
# [44,] -0.79590174
# [45,]  1.93906178
# [46,]  1.05993371
# [47,]  0.68857692
# [48,] -0.29758680
# [49,]  1.07903603
# [50,] -0.79590174
# [51,]  0.10317489
# [52,]  1.04609099
# [53,] -0.79590174
# [54,] -0.79590174
# [55,] -0.79590174
# [56,] -0.79590174
# [57,] -0.79590174
# [58,]  0.44562754
# [59,] -0.79590174
# [60,] -0.79590174
# [61,]  0.99346739

# %%
sum(pas)
# Out:
# [1] -5.440093e-15

# %%
mean(pas)
# Out:
# [1] -1.088019e-16

# %%
sd(pas)

# Why is important to standardize?
# z-score (scale)
  # in una distribuzione campanulare:
  # il 68% dei casi avrà uno z-score compreso tra -1 e 1 
  #(non più di 1 deviazione standard dalla media), 
  # il 95% sarà compreso tra -2 e 2 
  # e il 99.7% sarà compreso tra -3 e 3.
  # Inoltre, per qualsiasi distribuzione (non solo "campanulare"), 
  # il teorema di Chebyshev ci dice che la proporzione di valori 
  # con uno z-score assoluto superiore a k non è superiore a 1/k^2
  # to check the distribution of the variable a plot can be used
# Out:
# [1] 1

# %%
par(bg = "white")
plot(1:100, sort(pas))
# In this example the distribution is not "campanulare"
# Out:
# plot without title

# %%
par(bg = "white")
# let's focus only on those who has buy something
pas2 <- scale(Prezzo_acquisto[Prezzo_acquisto > 0])
mean(pas2)
sd(pas2)

plot(1:length(pas2), sort(pas2))
# Out:
# [1] -9.389652e-17
# [1] 1
# plot without title

# %%
par(bg = "white")
# We need to use the histogram graph
hist(pas)
# Out:
# Plot with title "Histogram of pas"

# %%
par(bg = "white")
hist(pas2)
# Out:
# Plot with title "Histogram of pas2"

# %%
par(bg = "white")
hist(pas2, breaks = 20)
# Out:
# Plot with title "Histogram of pas2"

# %% [markdown]
# #### <span style="color:#3182bd">Chebyshev Inequality</span>

# %% [markdown]
# ![Screenshot 2023-12-27 at 08.23.20.png](<attachment:Screenshot 2023-12-27 at 08.23.20.png>)

# %%
# Ci permette di individuare la proporzione di valori che si trovano
# a una distanza k dalla media
# This inequality is used to estimate the minimum amount 
# of data that is within a certain number of standard deviations from the mean
# minimal proportion of values that are at a distance k from the mean
# Use case: population that want to pay between 10 and 20
# k = 2
mean(Spesa_media_mensile) # 76.3609
sd(Spesa_media_mensile) # 12.7419
mean(Spesa_media_mensile) + 2 * sd(Spesa_media_mensile) # 101.8447
mean(Spesa_media_mensile) - 2 * sd(Spesa_media_mensile) # 50.8771
1 - 1/2^2
# 75% of the population is willing to pay between 51 and 102 euros
# Out:
# [1] 76.3609
# [1] 12.7419
# [1] 101.8447
# [1] 50.8771
# [1] 0.75

# %%
# create a function
cheb<-function(x, k){
  min <- mean(x) - k*sd(x)
  max <- mean(x) + k*sd(x)
  value <- 1 - 1/k^2
  return(c(min, max, value))
}

cheb(Spesa_media_mensile, 2) # 0.75
# Out:
# [1]  50.8771 101.8447   0.7500

# %% [markdown]
# #### <span style="color:#3182bd">Coefficient of variation</span>

# %% [markdown]
# ![Screenshot 2023-12-27 at 08.28.14.png](<attachment:Screenshot 2023-12-27 at 08.28.14.png>)

# %%
# variabilita della distribuzione tenendo conto della media aritmetica
# Indice di variablitita' relativa (Useful to compare distributions)
# CV (calcolare) coefficiente di variazione
# CV = sd/|mean|
# sqm / media in valore assoluto
# Absolute value divided by the mean
sd(Spesa_media_mensile)/abs(mean(Spesa_media_mensile)) # 0.1668 (16%)
# Out:
# [1] 0.1668642

# %%
# create a function
cv<-function(x){
  sd(x)/abs(mean(x)) * 100
}

cv(Spesa_media_mensile)
# Out:
# [1] 16.68642

# %% [markdown]
# #### <span style="color:#3182bd">Median absolute deviation</span>

# %%
# la mediana e' piu' robusta rispetto alla media
# mean absolute deviation from the median
# Why do we have to use this?
# MAD median absolute deviation
#? mad
mad(Spesa_media_mensile)
sd(Spesa_media_mensile)
var(Spesa_media_mensile)

range(Spesa_media_mensile)

mean(Spesa_media_mensile)
median(Spesa_media_mensile)
# Out:
# [1] 12.41677
# [1] 12.7419
# [1] 162.356
# [1]  44.38 103.94
# [1] 76.3609
# [1] 77.91

# %% [markdown]
# ### <span style="color:#31a354">Mutability Indexes
# </span>
# Indici di mutabilita' (Omogeneita' e Eterogeneita')</br>
# Variabili qualitative

# %% [markdown]
# #### <span style="color:#3182bd">Gini coefficient</span>

# %% [markdown]
# ![Screenshot 2023-12-27 at 08.49.36.png](<attachment:Screenshot 2023-12-27 at 08.49.36.png>)

# %%
# Qualitative data
# Massima omonogeneità (0) e massima eterogeneità (1)
gini<-function(x){
  if(is.factor(x)==FALSE){
    paste("La variabile deve essere di tipo factor")
    stop()
  }
  f<-as.numeric(table(x)/length(x))
  G<- 1 - sum(f^2)
  G_rel<- G * (length(f)/(length(f)-1))
  return(c("G"=G, "G_rel"=G_rel))
}

gini(Area_geografica)
gini(Livello_istruzione)

table(Livello_istruzione)
# Out:
#      G  G_rel
# 0.6578 0.9867
#         G     G_rel
# 0.7486000 0.9981333
# Livello_istruzione
#   Diploma    Laurea    Master Dottorato
#        28        23        24        25

# %%
# GPT
calculateGiniIndices <- function(frequencies) {
  k <- length(frequencies)
  total <- sum(frequencies)
  proportions <- frequencies / total
  
  # Gini Index
  G <- 1 - sum(proportions^2)
  
  # Maximum Gini Index
  Gmax <- (k - 1) / k
  
  # Normalized Gini Index
  G_star <- G / Gmax
  
  # Return a list containing all three indices
  return(list(G = G, Gmax = Gmax, G_star = G_star))
}
calculateGiniIndices(table(Area_geografica))
# Out:
# $G
# [1] 0.6578
#
# $Gmax
# [1] 0.6666667
#
# $G_star
# [1] 0.9867

# %% [markdown]
# ### <span style="color:#31a354">Shape indicators</span>
# Indici di forma

# %% [markdown]
# #### <span style="color:#3182bd">Skewness</span>

# %%
par(bg = "white")
hist(Prezzo_acquisto) # asimmetrica positiva
hist(-Prezzo_acquisto) # asimmetrica negativa
hist(rnorm(10000)) # simmetrica
# Out:
# Plot with title "Histogram of Prezzo_acquisto"
# Plot with title "Histogram of -Prezzo_acquisto"
# Plot with title "Histogram of rnorm(10000)"

# %% [markdown]
# #### <span style="color:#3182bd">Indice di Fisher</span>

# %% [markdown]
# ![Screenshot 2023-12-27 at 10.01.31.png](<attachment:Screenshot 2023-12-27 at 10.01.31.png>)

# %%
# Fisher's 
# Value = 0: simmetrica
# Value > 0: asimmetrica positiva
# Value < 0: asimmetrica negativa
# Generally we use the Fisher's coefficient and remove 3 by the result
asim_fisher <- function(x){
  if(is.numeric(x) == FALSE){
    paste("The input is not numeric")
    stop()
  }
  z <- scale(x)
  a <- mean(z^3)
  return(a)
}

asim_fisher(Prezzo_acquisto)
asim_fisher(rnorm(10000)) # Expected value = 0
# Out:
# [1] 0.8341645
# [1] 0.001245219

# %% [markdown]
# #### <span style="color:#3182bd">Kurtosis</span>

# %% [markdown]
# ![Screenshot 2023-12-27 at 10.10.44.png](<attachment:Screenshot 2023-12-27 at 10.10.44.png>)

# %%
# Kurtosis is a measure of whether the data are heavy-tailed or light-tailed
# platikurtic (light-tailed) or leptokurtic (heavy-tailed)
forma_fisher <- function(x){
  if(is.numeric(x) == FALSE){
    paste("The input is not numeric")
    stop()
  }
  z <- scale(x)
  a <- mean(z^3)
  k <- mean(z^4)-3
  return(c("Asimmetria" = a, "Curtosi" = k))
}

forma_fisher(Prezzo_acquisto) # more flat compare a normal distribution
forma_fisher(rnorm(10000)) # Expected values = 0, platikurtic
# Out:
# Asimmetria    Curtosi
#  0.8341645 -0.7741248
#   Asimmetria      Curtosi
# -0.001510742 -0.030972280

# %% [markdown]
# ### <span style="color:#31a354">Analisi delle distribuzioni per via Grafica</span>
# Analisi delle distribuzioni per via grafica

# %% [markdown]
# #### <span style="color:#3182bd">Stripchart</span>

# %%
par(bg = "white")
stripchart(Prezzo_acquisto)
# Out:
# plot without title

# %%
par(bg = "white")
stripchart(Prezzo_acquisto ~ Area_geografica)
# Out:
# plot without title

# %% [markdown]
# #### <span style="color:#3182bd">Stem and leaf plot</span>

# %%
stem(Prezzo_acquisto)
# Out:
#   The decimal point is 1 digit(s) to the right of the |
#
#   0 | 00000000000000000000000000000000000000000000000000000
#   1 | 256
#   2 | 056777889
#   3 | 237
#   4 | 0278
#   5 | 013488899
#   6 | 00138
#   7 | 66779
#   8 | 118
#   9 | 00347
#   10 | 0

# %% [markdown]
# #### <span style="color:#3182bd">Histogram</span>

# %%
par(bg = "white")
#?hist
hist(Spesa_media_mensile)
# Out:
# Plot with title "Histogram of Spesa_media_mensile"

# %%
par(bg = "white")
interval <- c(min(Spesa_media_mensile), 50, 75, 90, max(Spesa_media_mensile))
hist(Spesa_media_mensile, breaks = interval)
# Out:
# Plot with title "Histogram of Spesa_media_mensile"

# %%
par(bg = "white")
hist(Spesa_media_mensile, breaks = interval, probability = FALSE)
# Out:
# Warning message in plot.histogram(r, freq = freq1, col = col, border = border, angle = angle, :
# "le AREAS nel plot sono sbagliate -- si utilizzi 'freq = FALSE'"
# Plot with title "Histogram of Spesa_media_mensile"

# %%
par(bg = "white")
hist(Spesa_media_mensile, breaks =50)
# Out:
# Plot with title "Histogram of Spesa_media_mensile"

# %%
par(bg = "white")
hist(rnorm(1000), breaks =50)
# Out:
# Plot with title "Histogram of rnorm(1000)"

# %% [markdown]
# #### <span style="color:#3182bd">Density plot</span>

# %%
par(bg = "white")
# distribuzione di probabilità teorica 
# variabili discrete -> funzione di probabilità
# variabili continue -> funzione di densità di probabilità
density(Spesa_media_mensile)
plot(density(Spesa_media_mensile))

  # Density
# -	Argomenti  
# -	xlim , ylim, xlab, ylab, main 
# -	pch (simboli) 
# - cex (dimensione)  
# - col
# - lwd, lty = "blank", "solid", "dashed", "dotted", "dotdash", etc.
# - bty  "box type" = "o", "l", "7", "c", "u", or "]
# Out:
# Call:
# 	density.default(x = Spesa_media_mensile)
#
# Data: Spesa_media_mensile (100 obs.);	Bandwidth 'bw' = 4.455
#
#        x                y
#  Min.   : 31.02   Min.   :1.335e-05
#  1st Qu.: 52.59   1st Qu.:1.726e-03
#  Median : 74.16   Median :8.909e-03
#  Mean   : 74.16   Mean   :1.158e-02
#  3rd Qu.: 95.73   3rd Qu.:2.142e-02
#  Max.   :117.30   Max.   :3.056e-02
# Plot with title "density(x = Spesa_media_mensile)"

# %% [markdown]
# #### <span style="color:#3182bd">Histogram and density</span>

# %%
par(bg = "white")
hist(Spesa_media_mensile, probability = TRUE)
lines(density(Spesa_media_mensile), col=2)
# Out:
# Plot with title "Histogram of Spesa_media_mensile"

# %%
par(bg = "white")
hist(Spesa_media_mensile, probability = TRUE, ylim=c(0, 0.05))
lines(density(rnorm(100, 
                    mean(Spesa_media_mensile), 
                    sd(Spesa_media_mensile))), col=2)
# Out:
# Plot with title "Histogram of Spesa_media_mensile"

# %%
par(bg = "white")
hist(Spesa_media_mensile, probability = TRUE, ylim=c(0, 0.05), breaks = 18 )
lines(density(rnorm(100, 
                    mean(Spesa_media_mensile), 
                    sd(Spesa_media_mensile))), col=2)
# Out:
# Plot with title "Histogram of Spesa_media_mensile"

# %%
names(AcquistiOnLine)
# Out:
#  [1] "data_contatto"          "Nome"                   "Genere"
#  [4] "Et<U+00E0>"             "Area_geografica"        "Livello_istruzione"
#  [7] "Acquisto_online"        "Spesa_media_mensile"    "Prezzo_acquisto"
# [10] "Numero_pagine_visitate"

# %% [markdown]
# #### <span style="color:#3182bd">Boxplots</span>

# %% [markdown]
# ![Screenshot 2023-12-27 at 11.12.59.png](<attachment:Screenshot 2023-12-27 at 11.12.59.png>)

# %%
par(bg = "white")
#? boxplot
boxplot(Livello_istruzione) #1
# Out:
# plot without title

# %%
par(bg = "white")
boxplot(Spesa_media_mensile) #2
# Out:
# plot without title

# %%
par(bg = "white")
boxplot(Spesa_media_mensile, horizontal = T)    #3
# Out:
# plot without title

# %%
par(bg = "white")
par(mfrow=c(1,2))
boxplot(Spesa_media_mensile[Genere=="Femmina"], 
        main = "Femmina")       #4
boxplot(Spesa_media_mensile[Genere=="Maschio"],
        main="Maschio")        #4
# Out:
# Plot with title "Maschio"

# %%
par(bg = "white")       #4
par(mfrow=c(1,1))
boxplot(Spesa_media_mensile~Genere, col=c(2,3)) #5
# Out:
# plot without title

# %%
par(bg = "white")
boxplot(Spesa_media_mensile~Livello_istruzione, col=2:5)        #6
# Out:
# plot without title

# %% [markdown]
# #### <span style="color:#3182bd">Quantile graph: qqnorm</span>

# %%
par(bg = "white")
#? qqnorm
# Confronta le distribuzioni in temrmini di quantili
qqnorm(Spesa_media_mensile)

# Se i dati sono normali, i punti dovrebbero essere allineati sulla retta
qqline(Spesa_media_mensile)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
par(bg = "white")
# Standardize the data
# The graph is the same, but now we have the same scale
qqnorm(scale(Spesa_media_mensile))
qqline(scale(Spesa_media_mensile))
# Out:
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# #### <span style="color:#3182bd">Quantile graph: qqplot</span>

# %%
par(bg = "white")
#? qqplot
qqplot(Spesa_media_mensile,Prezzo_acquisto)

# If the arguments don't have the same length, doens't work
qqplot(Spesa_media_mensile[Genere=="Maschio"],
     Spesa_media_mensile[Genere=="Femmina"])
# abline(lsfit(Spesa_media_mensile[Genere=="Maschio"],
#      Spesa_media_mensile[Genere=="Femmina"]))


# lsfit() is used to fit a simple linear regression model
# lsfit(x, y, intercept = TRUE, ...)
# in our case x = Spesa_media_mensile[Genere=="Maschio"]
# and y = Spesa_media_mensile[Genere=="Femmina"]
abline(lsfit(
as.numeric(quantile(Spesa_media_mensile[Genere=="Maschio"], 
                    probs = seq(.01,.99,0.01))),
as.numeric(quantile(Spesa_media_mensile[Genere=="Femmina"], 
                    probs = seq(.01,.99,0.01))),
))
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## <span style="color:#e6550d">Variabili Categoriche </br>2.4 Categorical data</span>

# %% [markdown]
# #### <span style="color:#3182bd">Creazione di un nuovo oggetto factor</span>

# %%
# creazione di un oggetto factor
summary(AcquistiOnLine)  

Prezzo_acquisto_cat <- Prezzo_acquisto 
Prezzo_acquisto_cat[Prezzo_acquisto==0] <- 
  "01_Nessun acquisto"
Prezzo_acquisto_cat[Prezzo_acquisto > 0 & Prezzo_acquisto <= 25] <- 
  "02_Max 25 Euro"
Prezzo_acquisto_cat[Prezzo_acquisto > 25 & Prezzo_acquisto <= 50] <- 
  "03_tra 25 e 50 Euro"
Prezzo_acquisto_cat[Prezzo_acquisto >  50] <- 
  "04_Più di 50 Euro"

Prezzo_acquisto_cat<-factor(Prezzo_acquisto_cat, ordered = T)

AcquistiOnLine$Prezzo_acquisto_cat <- Prezzo_acquisto_cat

summary(Prezzo_acquisto_cat)
summary(AcquistiOnLine)
# Out:
#  data_contatto            Nome               Genere        Et<U+00E0>
#  Min.   :2020-01-03   Length:100         Femmina:56   Min.   :30.00
#  1st Qu.:2020-06-25   Class :character   Maschio:44   1st Qu.:36.00
#  Median :2020-12-16   Mode  :character                Median :43.00
#  Mean   :2021-01-01                                   Mean   :43.02
#  3rd Qu.:2021-07-16                                   3rd Qu.:50.00
#  Max.   :2021-12-27                                   Max.   :55.00
#     Area_geografica Livello_istruzione Acquisto_online Spesa_media_mensile
#  Centro     :39     Diploma  :28       No:53           Min.   : 44.38
#  Nord       :26     Laurea   :23       Si:47           1st Qu.: 69.56
#  Sud e isole:35     Master   :24                       Median : 77.91
#                     Dottorato:25                       Mean   : 76.36
#                                                        3rd Qu.: 86.22
#                                                        Max.   :103.94
#  Prezzo_acquisto Numero_pagine_visitate
#  Min.   : 0.00   Min.   :1.00
#  1st Qu.: 0.00   1st Qu.:2.00
#  Median : 0.00   Median :3.00
#  Mean   :25.69   Mean   :3.02
#  3rd Qu.:53.45   3rd Qu.:4.00
#  Max.   :99.69   Max.   :7.00
#       01_Nessun acquisto           02_Max 25 Euro      03_tra 25 e 50 Euro
#                       53                        4                       16
# 04_Pi<U+00F9> di 50 Euro
#                       27
#  data_contatto            Nome               Genere        Et<U+00E0>
#  Min.   :2020-01-03   Length:100         Femmina:56   Min.   :30.00
#  1st Qu.:2020-06-25   Class :character   Maschio:44   1st Qu.:36.00
#  Median :2020-12-16   Mode  :character                Median :43.00
#  Mean   :2021-01-01                                   Mean   :43.02
#  3rd Qu.:2021-07-16                                   3rd Qu.:50.00
#  Max.   :2021-12-27                                   Max.   :55.00
#     Area_geografica Livello_istruzione Acquisto_online Spesa_media_mensile
#  Centro     :39     Diploma  :28       No:53           Min.   : 44.38
#  Nord       :26     Laurea   :23       Si:47           1st Qu.: 69.56
#  Sud e isole:35     Master   :24                       Median : 77.91
#                     Dottorato:25                       Mean   : 76.36
#                                                        3rd Qu.: 86.22
#                                                        Max.   :103.94
#  Prezzo_acquisto Numero_pagine_visitate               Prezzo_acquisto_cat
#  Min.   : 0.00   Min.   :1.00           01_Nessun acquisto      :53
#  1st Qu.: 0.00   1st Qu.:2.00           02_Max 25 Euro          : 4
#  Median : 0.00   Median :3.00           03_tra 25 e 50 Euro     :16
#  Mean   :25.69   Mean   :3.02           04_Pi<U+00F9> di 50 Euro:27
#  3rd Qu.:53.45   3rd Qu.:4.00
#  Max.   :99.69   Max.   :7.00

# %% [markdown]
# #### <span style="color:#3182bd">table</span>

# %%
# frequenze assolute
table(Prezzo_acquisto_cat)
# frequenze relative
table(Prezzo_acquisto_cat)/length(Prezzo_acquisto_cat)

# distribuzioni doppie
table(Prezzo_acquisto_cat,Genere)
table(Prezzo_acquisto_cat,Genere)/length(Prezzo_acquisto_cat)
# Out:
# Prezzo_acquisto_cat
#       01_Nessun acquisto           02_Max 25 Euro      03_tra 25 e 50 Euro
#                       53                        4                       16
# 04_Pi<U+00F9> di 50 Euro
#                       27
# Prezzo_acquisto_cat
#       01_Nessun acquisto           02_Max 25 Euro      03_tra 25 e 50 Euro
#                     0.53                     0.04                     0.16
# 04_Pi<U+00F9> di 50 Euro
#                     0.27
#                           Genere
# Prezzo_acquisto_cat        Femmina Maschio
#   01_Nessun acquisto            29      24
#   02_Max 25 Euro                 3       1
#   03_tra 25 e 50 Euro            7       9
#   04_Pi<U+00F9> di 50 Euro      17      10
#                           Genere
# Prezzo_acquisto_cat        Femmina Maschio
#   01_Nessun acquisto          0.29    0.24
#   02_Max 25 Euro              0.03    0.01
#   03_tra 25 e 50 Euro         0.07    0.09
#   04_Pi<U+00F9> di 50 Euro    0.17    0.10

# %% [markdown]
# ### <span style="color:#31a354">Rappresentazioni Grafiche</span>

# %% [markdown]
# #### <span style="color:#3182bd">Bar charts</span>

# %%
par(bg = "white")
#? barplot
#! barplot need a table
# barplot(Area_geografica)

barplot(table(Area_geografica)) #1
# Out:
# plot without title

# %%
par(bg = "white")
barplot(table(Area_geografica)/length(Area_geografica)) #2
# Out:
# plot without title

# %%
par(bg = "white")
barplot(table(Area_geografica, Genere)) #3
# Out:
# plot without title

# %%
par(bg = "white")
barplot(table(Area_geografica, Genere)/length(Area_geografica)) #4
# Out:
# plot without title

# %%
par(bg = "white")
barplot(table(Genere,Area_geografica))  #5
# Out:
# plot without title

# %%
par(bg = "white")
barplot(Spesa_media_mensile[1:5] ~  Nome[1:5])  #6
# Out:
# plot without title

# %% [markdown]
# #### <span style="color:#3182bd">Dot charts</span>

# %%
par(bg = "white")
#? dotchart
dotchart(Spesa_media_mensile) # non ha un significato specifico #1
# Out:
# plot without title

# %%
par(bg = "white")
table(Area_geografica,Livello_istruzione)
dotchart(table(Area_geografica,Livello_istruzione)) #2
# Out:
#                Livello_istruzione
# Area_geografica Diploma Laurea Master Dottorato
#     Centro           11     11     10         7
#     Nord              7      6      3        10
#     Sud e isole      10      6     11         8
# plot without title

# %%
par(bg = "white")
dotchart(table(Livello_istruzione, Area_geografica)) #3
# Out:
# plot without title

# %%
par(bg = "white")
tab<-matrix(0, 
            length(unique(Area_geografica)), 
            length(unique(Livello_istruzione)))

for(i in 1:length(unique(Area_geografica)))
  for(j in 1:length(unique(Livello_istruzione)))
    tab[i,j] <- mean(Spesa_media_mensile
                     [Area_geografica == unique(Area_geografica)[i] & 
                      Livello_istruzione == unique(Livello_istruzione)[j]])
tab
rownames(tab)<-levels(Area_geografica)
colnames(tab)<-levels(Livello_istruzione)
tab

dotchart(tab, xlim = c(65,90), bg = "skyblue",
          main = "Spesa media mensile per livello di istruzione", 
          xlab = "Spesa media mensile",
          ylab = "Raggruppamento:  Livello di istruzione  x Area Geografica") #4
# Out:
#      [,1]     [,2]     [,3]     [,4]
# [1,] 72.36571 82.25200 74.49167 68.81333
# [2,] 73.06455 80.77571 82.77091 71.50300
# [3,] 73.49600 74.01750 69.45167 83.19636
#             Diploma  Laurea   Master   Dottorato
# Centro      72.36571 82.25200 74.49167 68.81333
# Nord        73.06455 80.77571 82.77091 71.50300
# Sud e isole 73.49600 74.01750 69.45167 83.19636
# Plot with title "Spesa media mensile per livello di istruzione"

# %%
par(bg = "white")
# Stessa tabella pero con le aree geografiche sulle righe, 
# usiamo la funzione t()
dotchart(t(tab), xlim = c(65,90), bg = "skyblue",
          main = "Spesa media mensile per area geografica", 
          xlab = "Spesa media mensile",
          ylab = "Raggruppamento: Area Geografica x Livello di istruzione")
# Out:
# Plot with title "Spesa media mensile per area geografica"

# %% [markdown]
# # <span style="color:#756bb1">Save and detach</span>

# %%
detach(AcquistiOnLine)
#! Set the proper working directory
#save.image("Wks_Univariata.RData")  

# Save the data frame with the new factor
#save(AcquistiOnLine, file = "AcquistiONLine.Rda")
